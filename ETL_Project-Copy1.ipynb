# %% [markdown]
# # ETL

# %%
# Import dependencies
import pandas as pd
import pymongo

# %%
# Read CSV file - World Happiness Report for 2019
df_2019=pd.read_csv('2019.csv',index_col=None)
#df_2019

# %%
#df_2019.info()

# %%
# Read CSV file - Income Group
df_inc = pd.read_csv(r'WB_Income_Group.csv', encoding='cp1252',index_col=None)
df_inc = df_inc.drop(columns='X')
df_inc = df_inc.dropna()
df_inc = df_inc.iloc[1:,:]
#df_inc

# %%
conn = 'mongodb://localhost:27017'

# %%
client = pymongo.MongoClient(conn)

# %%
db = client.happy_db

# %%
db.income_group.drop()
db.happy_ranking.drop()

# %%
df_inc.rename(columns = {'Income group':'IG'})
# Out:
#                    Country Code                      Region  \
# 1              Afghanistan  AFG                  South Asia
# 2                  Albania  ALB       Europe & Central Asia
# 3                  Algeria  DZA  Middle East & North Africa
# 4           American Samoa  ASM         East Asia & Pacific
# 5                  Andorra  AND       Europe & Central Asia
# ..                     ...  ...                         ...
# 214  Virgin Islands (U.S.)  VIR   Latin America & Caribbean
# 215     West Bank and Gaza  PSE  Middle East & North Africa
# 216            Yemen, Rep.  YEM  Middle East & North Africa
# 217                 Zambia  ZMB          Sub-Saharan Africa
# 218               Zimbabwe  ZWE          Sub-Saharan Africa
#
#                       IG
# 1             Low income
# 2    Upper middle income
# 3    Lower middle income
# 4    Upper middle income
# 5            High income
# ..                   ...
# 214          High income
# 215  Lower middle income
# 216           Low income
# 217  Lower middle income
# 218  Lower middle income
#
# [218 rows x 4 columns]

# %%
df_dict = df_inc.to_dict(orient='records').copy()

# %%
db.income_group.insert_many(df_dict)

# %%
cursor = db.income_group.find({})
for document in cursor:
    print(document)
# Out:
# {'_id': ObjectId('5fd505d0644cf0d4de07d509'), 'Country': 'Afghanistan', 'Code': 'AFG', 'Region': 'South Asia', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d50a'), 'Country': 'Albania', 'Code': 'ALB', 'Region': 'Europe & Central Asia', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d50b'), 'Country': 'Algeria', 'Code': 'DZA', 'Region': 'Middle East & North Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d50c'), 'Country': 'American Samoa', 'Code': 'ASM', 'Region': 'East Asia & Pacific', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d50d'), 'Country': 'Andorra', 'Code': 'AND', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d50e'), 'Country': 'Angola', 'Code': 'AGO', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d50f'), 'Country': 'Antigua and Barbuda', 'Code': 'ATG', 'Region': 'Latin America & Caribbean', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d510'), 'Country': 'Argentina', 'Code': 'ARG', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d511'), 'Country': 'Armenia', 'Code': 'ARM', 'Region': 'Europe & Central Asia', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d512'), 'Country': 'Aruba', 'Code': 'ABW', 'Region': 'Latin America & Caribbean', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d513'), 'Country': 'Australia', 'Code': 'AUS', 'Region': 'East Asia & Pacific', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d514'), 'Country': 'Austria', 'Code': 'AUT', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d515'), 'Country': 'Azerbaijan', 'Code': 'AZE', 'Region': 'Europe & Central Asia', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d516'), 'Country': 'Bahamas, The', 'Code': 'BHS', 'Region': 'Latin America & Caribbean', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d517'), 'Country': 'Bahrain', 'Code': 'BHR', 'Region': 'Middle East & North Africa', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d518'), 'Country': 'Bangladesh', 'Code': 'BGD', 'Region': 'South Asia', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d519'), 'Country': 'Barbados', 'Code': 'BRB', 'Region': 'Latin America & Caribbean', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d51a'), 'Country': 'Belarus', 'Code': 'BLR', 'Region': 'Europe & Central Asia', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d51b'), 'Country': 'Belgium', 'Code': 'BEL', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d51c'), 'Country': 'Belize', 'Code': 'BLZ', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d51d'), 'Country': 'Benin', 'Code': 'BEN', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d51e'), 'Country': 'Bermuda', 'Code': 'BMU', 'Region': 'North America', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d51f'), 'Country': 'Bhutan', 'Code': 'BTN', 'Region': 'South Asia', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d520'), 'Country': 'Bolivia', 'Code': 'BOL', 'Region': 'Latin America & Caribbean', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d521'), 'Country': 'Bosnia and Herzegovina', 'Code': 'BIH', 'Region': 'Europe & Central Asia', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d522'), 'Country': 'Botswana', 'Code': 'BWA', 'Region': 'Sub-Saharan Africa', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d523'), 'Country': 'Brazil', 'Code': 'BRA', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d524'), 'Country': 'British Virgin Islands', 'Code': 'VGB', 'Region': 'Latin America & Caribbean', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d525'), 'Country': 'Brunei Darussalam', 'Code': 'BRN', 'Region': 'East Asia & Pacific', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d526'), 'Country': 'Bulgaria', 'Code': 'BGR', 'Region': 'Europe & Central Asia', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d527'), 'Country': 'Burkina Faso', 'Code': 'BFA', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d528'), 'Country': 'Burundi', 'Code': 'BDI', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d529'), 'Country': 'Cabo Verde', 'Code': 'CPV', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d52a'), 'Country': 'Cambodia', 'Code': 'KHM', 'Region': 'East Asia & Pacific', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d52b'), 'Country': 'Cameroon', 'Code': 'CMR', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d52c'), 'Country': 'Canada', 'Code': 'CAN', 'Region': 'North America', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d52d'), 'Country': 'Cayman Islands', 'Code': 'CYM', 'Region': 'Latin America & Caribbean', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d52e'), 'Country': 'Central African Republic', 'Code': 'CAF', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d52f'), 'Country': 'Chad', 'Code': 'TCD', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d530'), 'Country': 'Channel Islands', 'Code': 'CHI', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d531'), 'Country': 'Chile', 'Code': 'CHL', 'Region': 'Latin America & Caribbean', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d532'), 'Country': 'China', 'Code': 'CHN', 'Region': 'East Asia & Pacific', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d533'), 'Country': 'Colombia', 'Code': 'COL', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d534'), 'Country': 'Comoros', 'Code': 'COM', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d535'), 'Country': 'Congo, Dem. Rep.', 'Code': 'COD', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d536'), 'Country': 'Congo, Rep.', 'Code': 'COG', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d537'), 'Country': 'Costa Rica', 'Code': 'CRI', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d538'), 'Country': "Côte d'Ivoire", 'Code': 'CIV', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d539'), 'Country': 'Croatia', 'Code': 'HRV', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d53a'), 'Country': 'Cuba', 'Code': 'CUB', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d53b'), 'Country': 'Curaçao', 'Code': 'CUW', 'Region': 'Latin America & Caribbean', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d53c'), 'Country': 'Cyprus', 'Code': 'CYP', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d53d'), 'Country': 'Czech Republic', 'Code': 'CZE', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d53e'), 'Country': 'Denmark', 'Code': 'DNK', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d53f'), 'Country': 'Djibouti', 'Code': 'DJI', 'Region': 'Middle East & North Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d540'), 'Country': 'Dominica', 'Code': 'DMA', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d541'), 'Country': 'Dominican Republic', 'Code': 'DOM', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d542'), 'Country': 'Ecuador', 'Code': 'ECU', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d543'), 'Country': 'Egypt, Arab Rep.', 'Code': 'EGY', 'Region': 'Middle East & North Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d544'), 'Country': 'El Salvador', 'Code': 'SLV', 'Region': 'Latin America & Caribbean', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d545'), 'Country': 'Equatorial Guinea', 'Code': 'GNQ', 'Region': 'Sub-Saharan Africa', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d546'), 'Country': 'Eritrea', 'Code': 'ERI', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d547'), 'Country': 'Estonia', 'Code': 'EST', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d548'), 'Country': 'Eswatini', 'Code': 'SWZ', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d549'), 'Country': 'Ethiopia', 'Code': 'ETH', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d54a'), 'Country': 'Faroe Islands', 'Code': 'FRO', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d54b'), 'Country': 'Fiji', 'Code': 'FJI', 'Region': 'East Asia & Pacific', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d54c'), 'Country': 'Finland', 'Code': 'FIN', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d54d'), 'Country': 'France', 'Code': 'FRA', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d54e'), 'Country': 'French Polynesia', 'Code': 'PYF', 'Region': 'East Asia & Pacific', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d54f'), 'Country': 'Gabon', 'Code': 'GAB', 'Region': 'Sub-Saharan Africa', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d550'), 'Country': 'Gambia, The', 'Code': 'GMB', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d551'), 'Country': 'Georgia', 'Code': 'GEO', 'Region': 'Europe & Central Asia', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d552'), 'Country': 'Germany', 'Code': 'DEU', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d553'), 'Country': 'Ghana', 'Code': 'GHA', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d554'), 'Country': 'Gibraltar', 'Code': 'GIB', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d555'), 'Country': 'Greece', 'Code': 'GRC', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d556'), 'Country': 'Greenland', 'Code': 'GRL', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d557'), 'Country': 'Grenada', 'Code': 'GRD', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d558'), 'Country': 'Guam', 'Code': 'GUM', 'Region': 'East Asia & Pacific', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d559'), 'Country': 'Guatemala', 'Code': 'GTM', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d55a'), 'Country': 'Guinea', 'Code': 'GIN', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d55b'), 'Country': 'Guinea-Bissau', 'Code': 'GNB', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d55c'), 'Country': 'Guyana', 'Code': 'GUY', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d55d'), 'Country': 'Haiti', 'Code': 'HTI', 'Region': 'Latin America & Caribbean', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d55e'), 'Country': 'Honduras', 'Code': 'HND', 'Region': 'Latin America & Caribbean', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d55f'), 'Country': 'Hong Kong SAR, China', 'Code': 'HKG', 'Region': 'East Asia & Pacific', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d560'), 'Country': 'Hungary', 'Code': 'HUN', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d561'), 'Country': 'Iceland', 'Code': 'ISL', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d562'), 'Country': 'India', 'Code': 'IND', 'Region': 'South Asia', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d563'), 'Country': 'Indonesia', 'Code': 'IDN', 'Region': 'East Asia & Pacific', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d564'), 'Country': 'Iran, Islamic Rep.', 'Code': 'IRN', 'Region': 'Middle East & North Africa', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d565'), 'Country': 'Iraq', 'Code': 'IRQ', 'Region': 'Middle East & North Africa', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d566'), 'Country': 'Ireland', 'Code': 'IRL', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d567'), 'Country': 'Isle of Man', 'Code': 'IMN', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d568'), 'Country': 'Israel', 'Code': 'ISR', 'Region': 'Middle East & North Africa', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d569'), 'Country': 'Italy', 'Code': 'ITA', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d56a'), 'Country': 'Jamaica', 'Code': 'JAM', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d56b'), 'Country': 'Japan', 'Code': 'JPN', 'Region': 'East Asia & Pacific', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d56c'), 'Country': 'Jordan', 'Code': 'JOR', 'Region': 'Middle East & North Africa', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d56d'), 'Country': 'Kazakhstan', 'Code': 'KAZ', 'Region': 'Europe & Central Asia', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d56e'), 'Country': 'Kenya', 'Code': 'KEN', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d56f'), 'Country': 'Kiribati', 'Code': 'KIR', 'Region': 'East Asia & Pacific', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d570'), 'Country': "Korea, Dem. People's Rep.", 'Code': 'PRK', 'Region': 'East Asia & Pacific', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d571'), 'Country': 'Korea, Rep.', 'Code': 'KOR', 'Region': 'East Asia & Pacific', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d572'), 'Country': 'Kosovo', 'Code': 'XKX', 'Region': 'Europe & Central Asia', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d573'), 'Country': 'Kuwait', 'Code': 'KWT', 'Region': 'Middle East & North Africa', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d574'), 'Country': 'Kyrgyz Republic', 'Code': 'KGZ', 'Region': 'Europe & Central Asia', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d575'), 'Country': 'Lao PDR', 'Code': 'LAO', 'Region': 'East Asia & Pacific', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d576'), 'Country': 'Latvia', 'Code': 'LVA', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d577'), 'Country': 'Lebanon', 'Code': 'LBN', 'Region': 'Middle East & North Africa', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d578'), 'Country': 'Lesotho', 'Code': 'LSO', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d579'), 'Country': 'Liberia', 'Code': 'LBR', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d57a'), 'Country': 'Libya', 'Code': 'LBY', 'Region': 'Middle East & North Africa', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d57b'), 'Country': 'Liechtenstein', 'Code': 'LIE', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d57c'), 'Country': 'Lithuania', 'Code': 'LTU', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d57d'), 'Country': 'Luxembourg', 'Code': 'LUX', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d57e'), 'Country': 'Macao SAR, China', 'Code': 'MAC', 'Region': 'East Asia & Pacific', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d57f'), 'Country': 'Madagascar', 'Code': 'MDG', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d580'), 'Country': 'Malawi', 'Code': 'MWI', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d581'), 'Country': 'Malaysia', 'Code': 'MYS', 'Region': 'East Asia & Pacific', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d582'), 'Country': 'Maldives', 'Code': 'MDV', 'Region': 'South Asia', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d583'), 'Country': 'Mali', 'Code': 'MLI', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d584'), 'Country': 'Malta', 'Code': 'MLT', 'Region': 'Middle East & North Africa', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d585'), 'Country': 'Marshall Islands', 'Code': 'MHL', 'Region': 'East Asia & Pacific', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d586'), 'Country': 'Mauritania', 'Code': 'MRT', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d587'), 'Country': 'Mauritius', 'Code': 'MUS', 'Region': 'Sub-Saharan Africa', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d588'), 'Country': 'Mexico', 'Code': 'MEX', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d589'), 'Country': 'Micronesia, Fed. Sts.', 'Code': 'FSM', 'Region': 'East Asia & Pacific', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d58a'), 'Country': 'Moldova', 'Code': 'MDA', 'Region': 'Europe & Central Asia', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d58b'), 'Country': 'Monaco', 'Code': 'MCO', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d58c'), 'Country': 'Mongolia', 'Code': 'MNG', 'Region': 'East Asia & Pacific', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d58d'), 'Country': 'Montenegro', 'Code': 'MNE', 'Region': 'Europe & Central Asia', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d58e'), 'Country': 'Morocco', 'Code': 'MAR', 'Region': 'Middle East & North Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d58f'), 'Country': 'Mozambique', 'Code': 'MOZ', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d590'), 'Country': 'Myanmar', 'Code': 'MMR', 'Region': 'East Asia & Pacific', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d591'), 'Country': 'Namibia', 'Code': 'NAM', 'Region': 'Sub-Saharan Africa', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d592'), 'Country': 'Nauru', 'Code': 'NRU', 'Region': 'East Asia & Pacific', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d593'), 'Country': 'Nepal', 'Code': 'NPL', 'Region': 'South Asia', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d594'), 'Country': 'Netherlands', 'Code': 'NLD', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d595'), 'Country': 'New Caledonia', 'Code': 'NCL', 'Region': 'East Asia & Pacific', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d596'), 'Country': 'New Zealand', 'Code': 'NZL', 'Region': 'East Asia & Pacific', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d597'), 'Country': 'Nicaragua', 'Code': 'NIC', 'Region': 'Latin America & Caribbean', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d598'), 'Country': 'Niger', 'Code': 'NER', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d599'), 'Country': 'Nigeria', 'Code': 'NGA', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d59a'), 'Country': 'North Macedonia', 'Code': 'MKD', 'Region': 'Europe & Central Asia', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d59b'), 'Country': 'Northern Mariana Islands', 'Code': 'MNP', 'Region': 'East Asia & Pacific', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d59c'), 'Country': 'Norway', 'Code': 'NOR', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d59d'), 'Country': 'Oman', 'Code': 'OMN', 'Region': 'Middle East & North Africa', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d59e'), 'Country': 'Pakistan', 'Code': 'PAK', 'Region': 'South Asia', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d59f'), 'Country': 'Palau', 'Code': 'PLW', 'Region': 'East Asia & Pacific', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5a0'), 'Country': 'Panama', 'Code': 'PAN', 'Region': 'Latin America & Caribbean', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5a1'), 'Country': 'Papua New Guinea', 'Code': 'PNG', 'Region': 'East Asia & Pacific', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5a2'), 'Country': 'Paraguay', 'Code': 'PRY', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5a3'), 'Country': 'Peru', 'Code': 'PER', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5a4'), 'Country': 'Philippines', 'Code': 'PHL', 'Region': 'East Asia & Pacific', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5a5'), 'Country': 'Poland', 'Code': 'POL', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5a6'), 'Country': 'Portugal', 'Code': 'PRT', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5a7'), 'Country': 'Puerto Rico', 'Code': 'PRI', 'Region': 'Latin America & Caribbean', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5a8'), 'Country': 'Qatar', 'Code': 'QAT', 'Region': 'Middle East & North Africa', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5a9'), 'Country': 'Romania', 'Code': 'ROU', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5aa'), 'Country': 'Russian Federation', 'Code': 'RUS', 'Region': 'Europe & Central Asia', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5ab'), 'Country': 'Rwanda', 'Code': 'RWA', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5ac'), 'Country': 'Samoa', 'Code': 'WSM', 'Region': 'East Asia & Pacific', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5ad'), 'Country': 'San Marino', 'Code': 'SMR', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5ae'), 'Country': 'São Tomé and Principe', 'Code': 'STP', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5af'), 'Country': 'Saudi Arabia', 'Code': 'SAU', 'Region': 'Middle East & North Africa', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5b0'), 'Country': 'Senegal', 'Code': 'SEN', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5b1'), 'Country': 'Serbia', 'Code': 'SRB', 'Region': 'Europe & Central Asia', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5b2'), 'Country': 'Seychelles', 'Code': 'SYC', 'Region': 'Sub-Saharan Africa', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5b3'), 'Country': 'Sierra Leone', 'Code': 'SLE', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5b4'), 'Country': 'Singapore', 'Code': 'SGP', 'Region': 'East Asia & Pacific', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5b5'), 'Country': 'Sint Maarten (Dutch part)', 'Code': 'SXM', 'Region': 'Latin America & Caribbean', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5b6'), 'Country': 'Slovak Republic', 'Code': 'SVK', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5b7'), 'Country': 'Slovenia', 'Code': 'SVN', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5b8'), 'Country': 'Solomon Islands', 'Code': 'SLB', 'Region': 'East Asia & Pacific', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5b9'), 'Country': 'Somalia', 'Code': 'SOM', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5ba'), 'Country': 'South Africa', 'Code': 'ZAF', 'Region': 'Sub-Saharan Africa', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5bb'), 'Country': 'South Sudan', 'Code': 'SSD', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5bc'), 'Country': 'Spain', 'Code': 'ESP', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5bd'), 'Country': 'Sri Lanka', 'Code': 'LKA', 'Region': 'South Asia', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5be'), 'Country': 'St. Kitts and Nevis', 'Code': 'KNA', 'Region': 'Latin America & Caribbean', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5bf'), 'Country': 'St. Lucia', 'Code': 'LCA', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5c0'), 'Country': 'St. Martin (French part)', 'Code': 'MAF', 'Region': 'Latin America & Caribbean', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5c1'), 'Country': 'St. Vincent and the Grenadines', 'Code': 'VCT', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5c2'), 'Country': 'Sudan', 'Code': 'SDN', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5c3'), 'Country': 'Suriname', 'Code': 'SUR', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5c4'), 'Country': 'Sweden', 'Code': 'SWE', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5c5'), 'Country': 'Switzerland', 'Code': 'CHE', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5c6'), 'Country': 'Syrian Arab Republic', 'Code': 'SYR', 'Region': 'Middle East & North Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5c7'), 'Country': 'Taiwan, China', 'Code': 'TWN', 'Region': 'East Asia & Pacific', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5c8'), 'Country': 'Tajikistan', 'Code': 'TJK', 'Region': 'Europe & Central Asia', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5c9'), 'Country': 'Tanzania', 'Code': 'TZA', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5ca'), 'Country': 'Thailand', 'Code': 'THA', 'Region': 'East Asia & Pacific', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5cb'), 'Country': 'Timor-Leste', 'Code': 'TLS', 'Region': 'East Asia & Pacific', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5cc'), 'Country': 'Togo', 'Code': 'TGO', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5cd'), 'Country': 'Tonga', 'Code': 'TON', 'Region': 'East Asia & Pacific', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5ce'), 'Country': 'Trinidad and Tobago', 'Code': 'TTO', 'Region': 'Latin America & Caribbean', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5cf'), 'Country': 'Tunisia', 'Code': 'TUN', 'Region': 'Middle East & North Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5d0'), 'Country': 'Turkey', 'Code': 'TUR', 'Region': 'Europe & Central Asia', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5d1'), 'Country': 'Turkmenistan', 'Code': 'TKM', 'Region': 'Europe & Central Asia', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5d2'), 'Country': 'Turks and Caicos Islands', 'Code': 'TCA', 'Region': 'Latin America & Caribbean', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5d3'), 'Country': 'Tuvalu', 'Code': 'TUV', 'Region': 'East Asia & Pacific', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5d4'), 'Country': 'Uganda', 'Code': 'UGA', 'Region': 'Sub-Saharan Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5d5'), 'Country': 'Ukraine', 'Code': 'UKR', 'Region': 'Europe & Central Asia', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5d6'), 'Country': 'United Arab Emirates', 'Code': 'ARE', 'Region': 'Middle East & North Africa', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5d7'), 'Country': 'United Kingdom', 'Code': 'GBR', 'Region': 'Europe & Central Asia', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5d8'), 'Country': 'United States', 'Code': 'USA', 'Region': 'North America', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5d9'), 'Country': 'Uruguay', 'Code': 'URY', 'Region': 'Latin America & Caribbean', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5da'), 'Country': 'Uzbekistan', 'Code': 'UZB', 'Region': 'Europe & Central Asia', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5db'), 'Country': 'Vanuatu', 'Code': 'VUT', 'Region': 'East Asia & Pacific', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5dc'), 'Country': 'Venezuela, RB', 'Code': 'VEN', 'Region': 'Latin America & Caribbean', 'Income group': 'Upper middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5dd'), 'Country': 'Vietnam', 'Code': 'VNM', 'Region': 'East Asia & Pacific', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5de'), 'Country': 'Virgin Islands (U.S.)', 'Code': 'VIR', 'Region': 'Latin America & Caribbean', 'Income group': 'High income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5df'), 'Country': 'West Bank and Gaza', 'Code': 'PSE', 'Region': 'Middle East & North Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5e0'), 'Country': 'Yemen, Rep.', 'Code': 'YEM', 'Region': 'Middle East & North Africa', 'Income group': 'Low income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5e1'), 'Country': 'Zambia', 'Code': 'ZMB', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}
# {'_id': ObjectId('5fd505d0644cf0d4de07d5e2'), 'Country': 'Zimbabwe', 'Code': 'ZWE', 'Region': 'Sub-Saharan Africa', 'Income group': 'Lower middle income'}

# %%
df_2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# 1             1.573                    0.996                         0.592
# 2             1.582                    1.028                         0.603
# 3             1.624                    1.026                         0.591
# 4             1.522                    0.999                         0.557
# ..              ...                      ...                           ...
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 0         0.153                      0.393
# 1         0.252                      0.410
# 2         0.271                      0.341
# 3         0.354                      0.118
# 4         0.322                      0.298
# ..          ...                        ...
# 151       0.217                      0.411
# 152       0.276                      0.147
# 153       0.158                      0.025
# 154       0.235                      0.035
# 155       0.202                      0.091
#
# [156 rows x 9 columns]

# %%
df_happy_dict = df_2019.to_dict(orient='records').copy()

# %%
#df_happy_dict

# %%
db.happy_ranking.insert_many(df_happy_dict)

# %%
cursor = db.happy_ranking.find({})
for document in cursor:
    print(document)
# Out:
# {'_id': ObjectId('5fd505d5644cf0d4de07d5e3'), 'Overall rank': 1, 'Country or region': 'Finland', 'Score': 7.769, 'GDP per capita': 1.34, 'Social support': 1.587, 'Healthy life expectancy': 0.986, 'Freedom to make life choices': 0.596, 'Generosity': 0.153, 'Perceptions of corruption': 0.39299999999999996}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5e4'), 'Overall rank': 2, 'Country or region': 'Denmark', 'Score': 7.6, 'GDP per capita': 1.383, 'Social support': 1.5730000000000002, 'Healthy life expectancy': 0.996, 'Freedom to make life choices': 0.5920000000000001, 'Generosity': 0.252, 'Perceptions of corruption': 0.41}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5e5'), 'Overall rank': 3, 'Country or region': 'Norway', 'Score': 7.553999999999999, 'GDP per capita': 1.4880000000000002, 'Social support': 1.5819999999999999, 'Healthy life expectancy': 1.028, 'Freedom to make life choices': 0.603, 'Generosity': 0.271, 'Perceptions of corruption': 0.341}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5e6'), 'Overall rank': 4, 'Country or region': 'Iceland', 'Score': 7.494, 'GDP per capita': 1.38, 'Social support': 1.624, 'Healthy life expectancy': 1.026, 'Freedom to make life choices': 0.591, 'Generosity': 0.354, 'Perceptions of corruption': 0.11800000000000001}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5e7'), 'Overall rank': 5, 'Country or region': 'Netherlands', 'Score': 7.4879999999999995, 'GDP per capita': 1.396, 'Social support': 1.5219999999999998, 'Healthy life expectancy': 0.9990000000000001, 'Freedom to make life choices': 0.557, 'Generosity': 0.322, 'Perceptions of corruption': 0.298}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5e8'), 'Overall rank': 6, 'Country or region': 'Switzerland', 'Score': 7.48, 'GDP per capita': 1.452, 'Social support': 1.526, 'Healthy life expectancy': 1.052, 'Freedom to make life choices': 0.5720000000000001, 'Generosity': 0.263, 'Perceptions of corruption': 0.34299999999999997}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5e9'), 'Overall rank': 7, 'Country or region': 'Sweden', 'Score': 7.343, 'GDP per capita': 1.3869999999999998, 'Social support': 1.4869999999999999, 'Healthy life expectancy': 1.0090000000000001, 'Freedom to make life choices': 0.574, 'Generosity': 0.267, 'Perceptions of corruption': 0.373}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5ea'), 'Overall rank': 8, 'Country or region': 'New Zealand', 'Score': 7.307, 'GDP per capita': 1.3030000000000002, 'Social support': 1.557, 'Healthy life expectancy': 1.026, 'Freedom to make life choices': 0.585, 'Generosity': 0.33, 'Perceptions of corruption': 0.38}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5eb'), 'Overall rank': 9, 'Country or region': 'Canada', 'Score': 7.278, 'GDP per capita': 1.365, 'Social support': 1.505, 'Healthy life expectancy': 1.0390000000000001, 'Freedom to make life choices': 0.584, 'Generosity': 0.285, 'Perceptions of corruption': 0.308}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5ec'), 'Overall rank': 10, 'Country or region': 'Austria', 'Score': 7.246, 'GDP per capita': 1.376, 'Social support': 1.475, 'Healthy life expectancy': 1.016, 'Freedom to make life choices': 0.532, 'Generosity': 0.244, 'Perceptions of corruption': 0.226}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5ed'), 'Overall rank': 11, 'Country or region': 'Australia', 'Score': 7.228, 'GDP per capita': 1.3719999999999999, 'Social support': 1.548, 'Healthy life expectancy': 1.036, 'Freedom to make life choices': 0.557, 'Generosity': 0.332, 'Perceptions of corruption': 0.29}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5ee'), 'Overall rank': 12, 'Country or region': 'Costa Rica', 'Score': 7.167000000000001, 'GDP per capita': 1.034, 'Social support': 1.4409999999999998, 'Healthy life expectancy': 0.963, 'Freedom to make life choices': 0.5579999999999999, 'Generosity': 0.14400000000000002, 'Perceptions of corruption': 0.09300000000000001}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5ef'), 'Overall rank': 13, 'Country or region': 'Israel', 'Score': 7.138999999999999, 'GDP per capita': 1.276, 'Social support': 1.455, 'Healthy life expectancy': 1.0290000000000001, 'Freedom to make life choices': 0.371, 'Generosity': 0.261, 'Perceptions of corruption': 0.08199999999999999}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5f0'), 'Overall rank': 14, 'Country or region': 'Luxembourg', 'Score': 7.09, 'GDP per capita': 1.609, 'Social support': 1.479, 'Healthy life expectancy': 1.012, 'Freedom to make life choices': 0.526, 'Generosity': 0.19399999999999998, 'Perceptions of corruption': 0.316}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5f1'), 'Overall rank': 15, 'Country or region': 'United Kingdom', 'Score': 7.053999999999999, 'GDP per capita': 1.3330000000000002, 'Social support': 1.538, 'Healthy life expectancy': 0.996, 'Freedom to make life choices': 0.45, 'Generosity': 0.348, 'Perceptions of corruption': 0.278}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5f2'), 'Overall rank': 16, 'Country or region': 'Ireland', 'Score': 7.021, 'GDP per capita': 1.499, 'Social support': 1.5530000000000002, 'Healthy life expectancy': 0.9990000000000001, 'Freedom to make life choices': 0.516, 'Generosity': 0.298, 'Perceptions of corruption': 0.31}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5f3'), 'Overall rank': 17, 'Country or region': 'Germany', 'Score': 6.985, 'GDP per capita': 1.3730000000000002, 'Social support': 1.454, 'Healthy life expectancy': 0.987, 'Freedom to make life choices': 0.495, 'Generosity': 0.261, 'Perceptions of corruption': 0.265}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5f4'), 'Overall rank': 18, 'Country or region': 'Belgium', 'Score': 6.922999999999999, 'GDP per capita': 1.3559999999999999, 'Social support': 1.504, 'Healthy life expectancy': 0.986, 'Freedom to make life choices': 0.473, 'Generosity': 0.16, 'Perceptions of corruption': 0.21}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5f5'), 'Overall rank': 19, 'Country or region': 'United States', 'Score': 6.892, 'GDP per capita': 1.433, 'Social support': 1.4569999999999999, 'Healthy life expectancy': 0.8740000000000001, 'Freedom to make life choices': 0.45399999999999996, 'Generosity': 0.28, 'Perceptions of corruption': 0.128}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5f6'), 'Overall rank': 20, 'Country or region': 'Czech Republic', 'Score': 6.852, 'GDP per capita': 1.2690000000000001, 'Social support': 1.4869999999999999, 'Healthy life expectancy': 0.92, 'Freedom to make life choices': 0.457, 'Generosity': 0.046, 'Perceptions of corruption': 0.036000000000000004}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5f7'), 'Overall rank': 21, 'Country or region': 'United Arab Emirates', 'Score': 6.825, 'GDP per capita': 1.5030000000000001, 'Social support': 1.31, 'Healthy life expectancy': 0.825, 'Freedom to make life choices': 0.598, 'Generosity': 0.262, 'Perceptions of corruption': 0.182}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5f8'), 'Overall rank': 22, 'Country or region': 'Malta', 'Score': 6.726, 'GDP per capita': 1.3, 'Social support': 1.52, 'Healthy life expectancy': 0.9990000000000001, 'Freedom to make life choices': 0.564, 'Generosity': 0.375, 'Perceptions of corruption': 0.151}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5f9'), 'Overall rank': 23, 'Country or region': 'Mexico', 'Score': 6.595, 'GDP per capita': 1.07, 'Social support': 1.3230000000000002, 'Healthy life expectancy': 0.861, 'Freedom to make life choices': 0.433, 'Generosity': 0.07400000000000001, 'Perceptions of corruption': 0.073}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5fa'), 'Overall rank': 24, 'Country or region': 'France', 'Score': 6.5920000000000005, 'GDP per capita': 1.324, 'Social support': 1.472, 'Healthy life expectancy': 1.045, 'Freedom to make life choices': 0.436, 'Generosity': 0.111, 'Perceptions of corruption': 0.183}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5fb'), 'Overall rank': 25, 'Country or region': 'Taiwan', 'Score': 6.446000000000001, 'GDP per capita': 1.368, 'Social support': 1.43, 'Healthy life expectancy': 0.914, 'Freedom to make life choices': 0.35100000000000003, 'Generosity': 0.242, 'Perceptions of corruption': 0.09699999999999999}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5fc'), 'Overall rank': 26, 'Country or region': 'Chile', 'Score': 6.444, 'GDP per capita': 1.159, 'Social support': 1.369, 'Healthy life expectancy': 0.92, 'Freedom to make life choices': 0.35700000000000004, 'Generosity': 0.187, 'Perceptions of corruption': 0.055999999999999994}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5fd'), 'Overall rank': 27, 'Country or region': 'Guatemala', 'Score': 6.436, 'GDP per capita': 0.8, 'Social support': 1.2690000000000001, 'Healthy life expectancy': 0.746, 'Freedom to make life choices': 0.535, 'Generosity': 0.175, 'Perceptions of corruption': 0.078}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5fe'), 'Overall rank': 28, 'Country or region': 'Saudi Arabia', 'Score': 6.375, 'GDP per capita': 1.403, 'Social support': 1.357, 'Healthy life expectancy': 0.795, 'Freedom to make life choices': 0.439, 'Generosity': 0.08, 'Perceptions of corruption': 0.132}
# {'_id': ObjectId('5fd505d5644cf0d4de07d5ff'), 'Overall rank': 29, 'Country or region': 'Qatar', 'Score': 6.374, 'GDP per capita': 1.6840000000000002, 'Social support': 1.3130000000000002, 'Healthy life expectancy': 0.871, 'Freedom to make life choices': 0.555, 'Generosity': 0.22, 'Perceptions of corruption': 0.16699999999999998}
# {'_id': ObjectId('5fd505d5644cf0d4de07d600'), 'Overall rank': 30, 'Country or region': 'Spain', 'Score': 6.354, 'GDP per capita': 1.286, 'Social support': 1.484, 'Healthy life expectancy': 1.062, 'Freedom to make life choices': 0.36200000000000004, 'Generosity': 0.153, 'Perceptions of corruption': 0.079}
# {'_id': ObjectId('5fd505d5644cf0d4de07d601'), 'Overall rank': 31, 'Country or region': 'Panama', 'Score': 6.321000000000001, 'GDP per capita': 1.149, 'Social support': 1.442, 'Healthy life expectancy': 0.91, 'Freedom to make life choices': 0.516, 'Generosity': 0.109, 'Perceptions of corruption': 0.054000000000000006}
# {'_id': ObjectId('5fd505d5644cf0d4de07d602'), 'Overall rank': 32, 'Country or region': 'Brazil', 'Score': 6.3, 'GDP per capita': 1.004, 'Social support': 1.439, 'Healthy life expectancy': 0.802, 'Freedom to make life choices': 0.39, 'Generosity': 0.099, 'Perceptions of corruption': 0.086}
# {'_id': ObjectId('5fd505d5644cf0d4de07d603'), 'Overall rank': 33, 'Country or region': 'Uruguay', 'Score': 6.292999999999999, 'GDP per capita': 1.124, 'Social support': 1.465, 'Healthy life expectancy': 0.8909999999999999, 'Freedom to make life choices': 0.523, 'Generosity': 0.127, 'Perceptions of corruption': 0.15}
# {'_id': ObjectId('5fd505d5644cf0d4de07d604'), 'Overall rank': 34, 'Country or region': 'Singapore', 'Score': 6.2620000000000005, 'GDP per capita': 1.5719999999999998, 'Social support': 1.463, 'Healthy life expectancy': 1.141, 'Freedom to make life choices': 0.556, 'Generosity': 0.271, 'Perceptions of corruption': 0.45299999999999996}
# {'_id': ObjectId('5fd505d5644cf0d4de07d605'), 'Overall rank': 35, 'Country or region': 'El Salvador', 'Score': 6.252999999999999, 'GDP per capita': 0.794, 'Social support': 1.242, 'Healthy life expectancy': 0.789, 'Freedom to make life choices': 0.43, 'Generosity': 0.09300000000000001, 'Perceptions of corruption': 0.07400000000000001}
# {'_id': ObjectId('5fd505d5644cf0d4de07d606'), 'Overall rank': 36, 'Country or region': 'Italy', 'Score': 6.223, 'GDP per capita': 1.294, 'Social support': 1.4880000000000002, 'Healthy life expectancy': 1.0390000000000001, 'Freedom to make life choices': 0.231, 'Generosity': 0.158, 'Perceptions of corruption': 0.03}
# {'_id': ObjectId('5fd505d5644cf0d4de07d607'), 'Overall rank': 37, 'Country or region': 'Bahrain', 'Score': 6.199, 'GDP per capita': 1.3619999999999999, 'Social support': 1.368, 'Healthy life expectancy': 0.871, 'Freedom to make life choices': 0.536, 'Generosity': 0.255, 'Perceptions of corruption': 0.11}
# {'_id': ObjectId('5fd505d5644cf0d4de07d608'), 'Overall rank': 38, 'Country or region': 'Slovakia', 'Score': 6.1979999999999995, 'GDP per capita': 1.246, 'Social support': 1.504, 'Healthy life expectancy': 0.8809999999999999, 'Freedom to make life choices': 0.33399999999999996, 'Generosity': 0.121, 'Perceptions of corruption': 0.013999999999999999}
# {'_id': ObjectId('5fd505d5644cf0d4de07d609'), 'Overall rank': 39, 'Country or region': 'Trinidad & Tobago', 'Score': 6.192, 'GDP per capita': 1.2309999999999999, 'Social support': 1.4769999999999999, 'Healthy life expectancy': 0.713, 'Freedom to make life choices': 0.489, 'Generosity': 0.185, 'Perceptions of corruption': 0.016}
# {'_id': ObjectId('5fd505d5644cf0d4de07d60a'), 'Overall rank': 40, 'Country or region': 'Poland', 'Score': 6.182, 'GDP per capita': 1.206, 'Social support': 1.4380000000000002, 'Healthy life expectancy': 0.884, 'Freedom to make life choices': 0.483, 'Generosity': 0.11699999999999999, 'Perceptions of corruption': 0.05}
# {'_id': ObjectId('5fd505d5644cf0d4de07d60b'), 'Overall rank': 41, 'Country or region': 'Uzbekistan', 'Score': 6.1739999999999995, 'GDP per capita': 0.745, 'Social support': 1.5290000000000001, 'Healthy life expectancy': 0.7559999999999999, 'Freedom to make life choices': 0.631, 'Generosity': 0.322, 'Perceptions of corruption': 0.24}
# {'_id': ObjectId('5fd505d5644cf0d4de07d60c'), 'Overall rank': 42, 'Country or region': 'Lithuania', 'Score': 6.149, 'GDP per capita': 1.238, 'Social support': 1.515, 'Healthy life expectancy': 0.818, 'Freedom to make life choices': 0.29100000000000004, 'Generosity': 0.043, 'Perceptions of corruption': 0.042}
# {'_id': ObjectId('5fd505d5644cf0d4de07d60d'), 'Overall rank': 43, 'Country or region': 'Colombia', 'Score': 6.125, 'GDP per capita': 0.985, 'Social support': 1.41, 'Healthy life expectancy': 0.841, 'Freedom to make life choices': 0.47, 'Generosity': 0.099, 'Perceptions of corruption': 0.034}
# {'_id': ObjectId('5fd505d5644cf0d4de07d60e'), 'Overall rank': 44, 'Country or region': 'Slovenia', 'Score': 6.117999999999999, 'GDP per capita': 1.258, 'Social support': 1.5230000000000001, 'Healthy life expectancy': 0.953, 'Freedom to make life choices': 0.564, 'Generosity': 0.14400000000000002, 'Perceptions of corruption': 0.057}
# {'_id': ObjectId('5fd505d5644cf0d4de07d60f'), 'Overall rank': 45, 'Country or region': 'Nicaragua', 'Score': 6.105, 'GDP per capita': 0.6940000000000001, 'Social support': 1.325, 'Healthy life expectancy': 0.835, 'Freedom to make life choices': 0.435, 'Generosity': 0.2, 'Perceptions of corruption': 0.127}
# {'_id': ObjectId('5fd505d5644cf0d4de07d610'), 'Overall rank': 46, 'Country or region': 'Kosovo', 'Score': 6.1, 'GDP per capita': 0.882, 'Social support': 1.232, 'Healthy life expectancy': 0.758, 'Freedom to make life choices': 0.489, 'Generosity': 0.262, 'Perceptions of corruption': 0.006}
# {'_id': ObjectId('5fd505d5644cf0d4de07d611'), 'Overall rank': 47, 'Country or region': 'Argentina', 'Score': 6.086, 'GDP per capita': 1.092, 'Social support': 1.432, 'Healthy life expectancy': 0.8809999999999999, 'Freedom to make life choices': 0.47100000000000003, 'Generosity': 0.066, 'Perceptions of corruption': 0.05}
# {'_id': ObjectId('5fd505d5644cf0d4de07d612'), 'Overall rank': 48, 'Country or region': 'Romania', 'Score': 6.07, 'GDP per capita': 1.162, 'Social support': 1.232, 'Healthy life expectancy': 0.825, 'Freedom to make life choices': 0.462, 'Generosity': 0.083, 'Perceptions of corruption': 0.005}
# {'_id': ObjectId('5fd505d5644cf0d4de07d613'), 'Overall rank': 49, 'Country or region': 'Cyprus', 'Score': 6.046, 'GDP per capita': 1.263, 'Social support': 1.2229999999999999, 'Healthy life expectancy': 1.042, 'Freedom to make life choices': 0.406, 'Generosity': 0.19, 'Perceptions of corruption': 0.040999999999999995}
# {'_id': ObjectId('5fd505d5644cf0d4de07d614'), 'Overall rank': 50, 'Country or region': 'Ecuador', 'Score': 6.028, 'GDP per capita': 0.912, 'Social support': 1.3119999999999998, 'Healthy life expectancy': 0.868, 'Freedom to make life choices': 0.498, 'Generosity': 0.126, 'Perceptions of corruption': 0.087}
# {'_id': ObjectId('5fd505d5644cf0d4de07d615'), 'Overall rank': 51, 'Country or region': 'Kuwait', 'Score': 6.021, 'GDP per capita': 1.5, 'Social support': 1.319, 'Healthy life expectancy': 0.8079999999999999, 'Freedom to make life choices': 0.493, 'Generosity': 0.142, 'Perceptions of corruption': 0.09699999999999999}
# {'_id': ObjectId('5fd505d5644cf0d4de07d616'), 'Overall rank': 52, 'Country or region': 'Thailand', 'Score': 6.007999999999999, 'GDP per capita': 1.05, 'Social support': 1.409, 'Healthy life expectancy': 0.828, 'Freedom to make life choices': 0.557, 'Generosity': 0.359, 'Perceptions of corruption': 0.027999999999999997}
# {'_id': ObjectId('5fd505d5644cf0d4de07d617'), 'Overall rank': 53, 'Country or region': 'Latvia', 'Score': 5.94, 'GDP per capita': 1.187, 'Social support': 1.465, 'Healthy life expectancy': 0.812, 'Freedom to make life choices': 0.264, 'Generosity': 0.075, 'Perceptions of corruption': 0.064}
# {'_id': ObjectId('5fd505d5644cf0d4de07d618'), 'Overall rank': 54, 'Country or region': 'South Korea', 'Score': 5.895, 'GDP per capita': 1.301, 'Social support': 1.219, 'Healthy life expectancy': 1.036, 'Freedom to make life choices': 0.159, 'Generosity': 0.175, 'Perceptions of corruption': 0.055999999999999994}
# {'_id': ObjectId('5fd505d5644cf0d4de07d619'), 'Overall rank': 55, 'Country or region': 'Estonia', 'Score': 5.893, 'GDP per capita': 1.237, 'Social support': 1.528, 'Healthy life expectancy': 0.8740000000000001, 'Freedom to make life choices': 0.495, 'Generosity': 0.10300000000000001, 'Perceptions of corruption': 0.161}
# {'_id': ObjectId('5fd505d5644cf0d4de07d61a'), 'Overall rank': 56, 'Country or region': 'Jamaica', 'Score': 5.89, 'GDP per capita': 0.831, 'Social support': 1.4780000000000002, 'Healthy life expectancy': 0.831, 'Freedom to make life choices': 0.49, 'Generosity': 0.107, 'Perceptions of corruption': 0.027999999999999997}
# {'_id': ObjectId('5fd505d5644cf0d4de07d61b'), 'Overall rank': 57, 'Country or region': 'Mauritius', 'Score': 5.888, 'GDP per capita': 1.12, 'Social support': 1.402, 'Healthy life expectancy': 0.7979999999999999, 'Freedom to make life choices': 0.498, 'Generosity': 0.215, 'Perceptions of corruption': 0.06}
# {'_id': ObjectId('5fd505d5644cf0d4de07d61c'), 'Overall rank': 58, 'Country or region': 'Japan', 'Score': 5.886, 'GDP per capita': 1.327, 'Social support': 1.419, 'Healthy life expectancy': 1.088, 'Freedom to make life choices': 0.445, 'Generosity': 0.069, 'Perceptions of corruption': 0.14}
# {'_id': ObjectId('5fd505d5644cf0d4de07d61d'), 'Overall rank': 59, 'Country or region': 'Honduras', 'Score': 5.86, 'GDP per capita': 0.642, 'Social support': 1.236, 'Healthy life expectancy': 0.828, 'Freedom to make life choices': 0.507, 'Generosity': 0.24600000000000002, 'Perceptions of corruption': 0.078}
# {'_id': ObjectId('5fd505d5644cf0d4de07d61e'), 'Overall rank': 60, 'Country or region': 'Kazakhstan', 'Score': 5.809, 'GDP per capita': 1.173, 'Social support': 1.508, 'Healthy life expectancy': 0.7290000000000001, 'Freedom to make life choices': 0.41, 'Generosity': 0.146, 'Perceptions of corruption': 0.096}
# {'_id': ObjectId('5fd505d5644cf0d4de07d61f'), 'Overall rank': 61, 'Country or region': 'Bolivia', 'Score': 5.779, 'GDP per capita': 0.7759999999999999, 'Social support': 1.209, 'Healthy life expectancy': 0.706, 'Freedom to make life choices': 0.511, 'Generosity': 0.13699999999999998, 'Perceptions of corruption': 0.064}
# {'_id': ObjectId('5fd505d5644cf0d4de07d620'), 'Overall rank': 62, 'Country or region': 'Hungary', 'Score': 5.757999999999999, 'GDP per capita': 1.2009999999999998, 'Social support': 1.41, 'Healthy life expectancy': 0.828, 'Freedom to make life choices': 0.19899999999999998, 'Generosity': 0.081, 'Perceptions of corruption': 0.02}
# {'_id': ObjectId('5fd505d5644cf0d4de07d621'), 'Overall rank': 63, 'Country or region': 'Paraguay', 'Score': 5.742999999999999, 'GDP per capita': 0.855, 'Social support': 1.475, 'Healthy life expectancy': 0.777, 'Freedom to make life choices': 0.514, 'Generosity': 0.184, 'Perceptions of corruption': 0.08}
# {'_id': ObjectId('5fd505d5644cf0d4de07d622'), 'Overall rank': 64, 'Country or region': 'Northern Cyprus', 'Score': 5.718, 'GDP per capita': 1.263, 'Social support': 1.252, 'Healthy life expectancy': 1.042, 'Freedom to make life choices': 0.41700000000000004, 'Generosity': 0.191, 'Perceptions of corruption': 0.162}
# {'_id': ObjectId('5fd505d5644cf0d4de07d623'), 'Overall rank': 65, 'Country or region': 'Peru', 'Score': 5.697, 'GDP per capita': 0.96, 'Social support': 1.274, 'Healthy life expectancy': 0.8540000000000001, 'Freedom to make life choices': 0.455, 'Generosity': 0.083, 'Perceptions of corruption': 0.027000000000000003}
# {'_id': ObjectId('5fd505d5644cf0d4de07d624'), 'Overall rank': 66, 'Country or region': 'Portugal', 'Score': 5.693, 'GDP per capita': 1.2209999999999999, 'Social support': 1.431, 'Healthy life expectancy': 0.9990000000000001, 'Freedom to make life choices': 0.508, 'Generosity': 0.047, 'Perceptions of corruption': 0.025}
# {'_id': ObjectId('5fd505d5644cf0d4de07d625'), 'Overall rank': 67, 'Country or region': 'Pakistan', 'Score': 5.653, 'GDP per capita': 0.677, 'Social support': 0.8859999999999999, 'Healthy life expectancy': 0.535, 'Freedom to make life choices': 0.313, 'Generosity': 0.22, 'Perceptions of corruption': 0.098}
# {'_id': ObjectId('5fd505d5644cf0d4de07d626'), 'Overall rank': 68, 'Country or region': 'Russia', 'Score': 5.648, 'GDP per capita': 1.183, 'Social support': 1.452, 'Healthy life expectancy': 0.726, 'Freedom to make life choices': 0.33399999999999996, 'Generosity': 0.08199999999999999, 'Perceptions of corruption': 0.031}
# {'_id': ObjectId('5fd505d5644cf0d4de07d627'), 'Overall rank': 69, 'Country or region': 'Philippines', 'Score': 5.631, 'GDP per capita': 0.807, 'Social support': 1.2930000000000001, 'Healthy life expectancy': 0.657, 'Freedom to make life choices': 0.5579999999999999, 'Generosity': 0.11699999999999999, 'Perceptions of corruption': 0.107}
# {'_id': ObjectId('5fd505d5644cf0d4de07d628'), 'Overall rank': 70, 'Country or region': 'Serbia', 'Score': 5.603, 'GDP per capita': 1.004, 'Social support': 1.383, 'Healthy life expectancy': 0.8540000000000001, 'Freedom to make life choices': 0.282, 'Generosity': 0.13699999999999998, 'Perceptions of corruption': 0.039}
# {'_id': ObjectId('5fd505d5644cf0d4de07d629'), 'Overall rank': 71, 'Country or region': 'Moldova', 'Score': 5.529, 'GDP per capita': 0.685, 'Social support': 1.328, 'Healthy life expectancy': 0.7390000000000001, 'Freedom to make life choices': 0.245, 'Generosity': 0.18100000000000002, 'Perceptions of corruption': 0.0}
# {'_id': ObjectId('5fd505d5644cf0d4de07d62a'), 'Overall rank': 72, 'Country or region': 'Libya', 'Score': 5.525, 'GDP per capita': 1.044, 'Social support': 1.3030000000000002, 'Healthy life expectancy': 0.6729999999999999, 'Freedom to make life choices': 0.41600000000000004, 'Generosity': 0.133, 'Perceptions of corruption': 0.152}
# {'_id': ObjectId('5fd505d5644cf0d4de07d62b'), 'Overall rank': 73, 'Country or region': 'Montenegro', 'Score': 5.523, 'GDP per capita': 1.051, 'Social support': 1.361, 'Healthy life expectancy': 0.871, 'Freedom to make life choices': 0.19699999999999998, 'Generosity': 0.142, 'Perceptions of corruption': 0.08}
# {'_id': ObjectId('5fd505d5644cf0d4de07d62c'), 'Overall rank': 74, 'Country or region': 'Tajikistan', 'Score': 5.4670000000000005, 'GDP per capita': 0.493, 'Social support': 1.0979999999999999, 'Healthy life expectancy': 0.718, 'Freedom to make life choices': 0.389, 'Generosity': 0.23, 'Perceptions of corruption': 0.14400000000000002}
# {'_id': ObjectId('5fd505d5644cf0d4de07d62d'), 'Overall rank': 75, 'Country or region': 'Croatia', 'Score': 5.432, 'GDP per capita': 1.155, 'Social support': 1.266, 'Healthy life expectancy': 0.914, 'Freedom to make life choices': 0.29600000000000004, 'Generosity': 0.11900000000000001, 'Perceptions of corruption': 0.022000000000000002}
# {'_id': ObjectId('5fd505d5644cf0d4de07d62e'), 'Overall rank': 76, 'Country or region': 'Hong Kong', 'Score': 5.43, 'GDP per capita': 1.4380000000000002, 'Social support': 1.2770000000000001, 'Healthy life expectancy': 1.122, 'Freedom to make life choices': 0.44, 'Generosity': 0.258, 'Perceptions of corruption': 0.287}
# {'_id': ObjectId('5fd505d5644cf0d4de07d62f'), 'Overall rank': 77, 'Country or region': 'Dominican Republic', 'Score': 5.425, 'GDP per capita': 1.015, 'Social support': 1.401, 'Healthy life expectancy': 0.779, 'Freedom to make life choices': 0.49700000000000005, 'Generosity': 0.113, 'Perceptions of corruption': 0.10099999999999999}
# {'_id': ObjectId('5fd505d5644cf0d4de07d630'), 'Overall rank': 78, 'Country or region': 'Bosnia and Herzegovina', 'Score': 5.386, 'GDP per capita': 0.945, 'Social support': 1.212, 'Healthy life expectancy': 0.845, 'Freedom to make life choices': 0.212, 'Generosity': 0.263, 'Perceptions of corruption': 0.006}
# {'_id': ObjectId('5fd505d5644cf0d4de07d631'), 'Overall rank': 79, 'Country or region': 'Turkey', 'Score': 5.372999999999999, 'GDP per capita': 1.183, 'Social support': 1.36, 'Healthy life expectancy': 0.8079999999999999, 'Freedom to make life choices': 0.195, 'Generosity': 0.083, 'Perceptions of corruption': 0.106}
# {'_id': ObjectId('5fd505d5644cf0d4de07d632'), 'Overall rank': 80, 'Country or region': 'Malaysia', 'Score': 5.3389999999999995, 'GDP per capita': 1.2209999999999999, 'Social support': 1.171, 'Healthy life expectancy': 0.828, 'Freedom to make life choices': 0.508, 'Generosity': 0.26, 'Perceptions of corruption': 0.024}
# {'_id': ObjectId('5fd505d5644cf0d4de07d633'), 'Overall rank': 81, 'Country or region': 'Belarus', 'Score': 5.3229999999999995, 'GDP per capita': 1.067, 'Social support': 1.465, 'Healthy life expectancy': 0.789, 'Freedom to make life choices': 0.235, 'Generosity': 0.094, 'Perceptions of corruption': 0.142}
# {'_id': ObjectId('5fd505d5644cf0d4de07d634'), 'Overall rank': 82, 'Country or region': 'Greece', 'Score': 5.287000000000001, 'GDP per capita': 1.181, 'Social support': 1.156, 'Healthy life expectancy': 0.9990000000000001, 'Freedom to make life choices': 0.067, 'Generosity': 0.0, 'Perceptions of corruption': 0.034}
# {'_id': ObjectId('5fd505d5644cf0d4de07d635'), 'Overall rank': 83, 'Country or region': 'Mongolia', 'Score': 5.285, 'GDP per capita': 0.948, 'Social support': 1.531, 'Healthy life expectancy': 0.667, 'Freedom to make life choices': 0.317, 'Generosity': 0.235, 'Perceptions of corruption': 0.038}
# {'_id': ObjectId('5fd505d5644cf0d4de07d636'), 'Overall rank': 84, 'Country or region': 'North Macedonia', 'Score': 5.274, 'GDP per capita': 0.983, 'Social support': 1.294, 'Healthy life expectancy': 0.838, 'Freedom to make life choices': 0.345, 'Generosity': 0.185, 'Perceptions of corruption': 0.034}
# {'_id': ObjectId('5fd505d5644cf0d4de07d637'), 'Overall rank': 85, 'Country or region': 'Nigeria', 'Score': 5.265, 'GDP per capita': 0.696, 'Social support': 1.111, 'Healthy life expectancy': 0.245, 'Freedom to make life choices': 0.426, 'Generosity': 0.215, 'Perceptions of corruption': 0.040999999999999995}
# {'_id': ObjectId('5fd505d5644cf0d4de07d638'), 'Overall rank': 86, 'Country or region': 'Kyrgyzstan', 'Score': 5.261, 'GDP per capita': 0.551, 'Social support': 1.4380000000000002, 'Healthy life expectancy': 0.723, 'Freedom to make life choices': 0.508, 'Generosity': 0.3, 'Perceptions of corruption': 0.023}
# {'_id': ObjectId('5fd505d5644cf0d4de07d639'), 'Overall rank': 87, 'Country or region': 'Turkmenistan', 'Score': 5.247000000000001, 'GDP per capita': 1.052, 'Social support': 1.538, 'Healthy life expectancy': 0.657, 'Freedom to make life choices': 0.39399999999999996, 'Generosity': 0.244, 'Perceptions of corruption': 0.027999999999999997}
# {'_id': ObjectId('5fd505d5644cf0d4de07d63a'), 'Overall rank': 88, 'Country or region': 'Algeria', 'Score': 5.211, 'GDP per capita': 1.002, 'Social support': 1.16, 'Healthy life expectancy': 0.785, 'Freedom to make life choices': 0.086, 'Generosity': 0.073, 'Perceptions of corruption': 0.114}
# {'_id': ObjectId('5fd505d5644cf0d4de07d63b'), 'Overall rank': 89, 'Country or region': 'Morocco', 'Score': 5.207999999999999, 'GDP per capita': 0.8009999999999999, 'Social support': 0.782, 'Healthy life expectancy': 0.782, 'Freedom to make life choices': 0.418, 'Generosity': 0.036000000000000004, 'Perceptions of corruption': 0.076}
# {'_id': ObjectId('5fd505d5644cf0d4de07d63c'), 'Overall rank': 90, 'Country or region': 'Azerbaijan', 'Score': 5.207999999999999, 'GDP per capita': 1.043, 'Social support': 1.147, 'Healthy life expectancy': 0.769, 'Freedom to make life choices': 0.35100000000000003, 'Generosity': 0.035, 'Perceptions of corruption': 0.182}
# {'_id': ObjectId('5fd505d5644cf0d4de07d63d'), 'Overall rank': 91, 'Country or region': 'Lebanon', 'Score': 5.197, 'GDP per capita': 0.987, 'Social support': 1.224, 'Healthy life expectancy': 0.815, 'Freedom to make life choices': 0.21600000000000003, 'Generosity': 0.166, 'Perceptions of corruption': 0.027000000000000003}
# {'_id': ObjectId('5fd505d5644cf0d4de07d63e'), 'Overall rank': 92, 'Country or region': 'Indonesia', 'Score': 5.192, 'GDP per capita': 0.9309999999999999, 'Social support': 1.203, 'Healthy life expectancy': 0.66, 'Freedom to make life choices': 0.491, 'Generosity': 0.498, 'Perceptions of corruption': 0.027999999999999997}
# {'_id': ObjectId('5fd505d5644cf0d4de07d63f'), 'Overall rank': 93, 'Country or region': 'China', 'Score': 5.191, 'GDP per capita': 1.0290000000000001, 'Social support': 1.125, 'Healthy life expectancy': 0.893, 'Freedom to make life choices': 0.521, 'Generosity': 0.057999999999999996, 'Perceptions of corruption': 0.1}
# {'_id': ObjectId('5fd505d5644cf0d4de07d640'), 'Overall rank': 94, 'Country or region': 'Vietnam', 'Score': 5.175, 'GDP per capita': 0.741, 'Social support': 1.3459999999999999, 'Healthy life expectancy': 0.851, 'Freedom to make life choices': 0.5429999999999999, 'Generosity': 0.147, 'Perceptions of corruption': 0.073}
# {'_id': ObjectId('5fd505d5644cf0d4de07d641'), 'Overall rank': 95, 'Country or region': 'Bhutan', 'Score': 5.082, 'GDP per capita': 0.813, 'Social support': 1.321, 'Healthy life expectancy': 0.604, 'Freedom to make life choices': 0.457, 'Generosity': 0.37, 'Perceptions of corruption': 0.16699999999999998}
# {'_id': ObjectId('5fd505d5644cf0d4de07d642'), 'Overall rank': 96, 'Country or region': 'Cameroon', 'Score': 5.044, 'GDP per capita': 0.5489999999999999, 'Social support': 0.91, 'Healthy life expectancy': 0.331, 'Freedom to make life choices': 0.381, 'Generosity': 0.187, 'Perceptions of corruption': 0.037000000000000005}
# {'_id': ObjectId('5fd505d5644cf0d4de07d643'), 'Overall rank': 97, 'Country or region': 'Bulgaria', 'Score': 5.011, 'GDP per capita': 1.092, 'Social support': 1.5130000000000001, 'Healthy life expectancy': 0.815, 'Freedom to make life choices': 0.311, 'Generosity': 0.081, 'Perceptions of corruption': 0.004}
# {'_id': ObjectId('5fd505d5644cf0d4de07d644'), 'Overall rank': 98, 'Country or region': 'Ghana', 'Score': 4.996, 'GDP per capita': 0.611, 'Social support': 0.868, 'Healthy life expectancy': 0.486, 'Freedom to make life choices': 0.381, 'Generosity': 0.245, 'Perceptions of corruption': 0.04}
# {'_id': ObjectId('5fd505d5644cf0d4de07d645'), 'Overall rank': 99, 'Country or region': 'Ivory Coast', 'Score': 4.944, 'GDP per capita': 0.569, 'Social support': 0.8079999999999999, 'Healthy life expectancy': 0.23199999999999998, 'Freedom to make life choices': 0.35200000000000004, 'Generosity': 0.154, 'Perceptions of corruption': 0.09}
# {'_id': ObjectId('5fd505d5644cf0d4de07d646'), 'Overall rank': 100, 'Country or region': 'Nepal', 'Score': 4.913, 'GDP per capita': 0.446, 'Social support': 1.226, 'Healthy life expectancy': 0.677, 'Freedom to make life choices': 0.439, 'Generosity': 0.285, 'Perceptions of corruption': 0.08900000000000001}
# {'_id': ObjectId('5fd505d5644cf0d4de07d647'), 'Overall rank': 101, 'Country or region': 'Jordan', 'Score': 4.906000000000001, 'GDP per capita': 0.8370000000000001, 'Social support': 1.225, 'Healthy life expectancy': 0.815, 'Freedom to make life choices': 0.38299999999999995, 'Generosity': 0.11, 'Perceptions of corruption': 0.13}
# {'_id': ObjectId('5fd505d5644cf0d4de07d648'), 'Overall rank': 102, 'Country or region': 'Benin', 'Score': 4.883, 'GDP per capita': 0.39299999999999996, 'Social support': 0.43700000000000006, 'Healthy life expectancy': 0.397, 'Freedom to make life choices': 0.349, 'Generosity': 0.175, 'Perceptions of corruption': 0.08199999999999999}
# {'_id': ObjectId('5fd505d5644cf0d4de07d649'), 'Overall rank': 103, 'Country or region': 'Congo (Brazzaville)', 'Score': 4.812, 'GDP per capita': 0.6729999999999999, 'Social support': 0.799, 'Healthy life expectancy': 0.508, 'Freedom to make life choices': 0.37200000000000005, 'Generosity': 0.105, 'Perceptions of corruption': 0.09300000000000001}
# {'_id': ObjectId('5fd505d5644cf0d4de07d64a'), 'Overall rank': 104, 'Country or region': 'Gabon', 'Score': 4.7989999999999995, 'GDP per capita': 1.057, 'Social support': 1.183, 'Healthy life expectancy': 0.5710000000000001, 'Freedom to make life choices': 0.295, 'Generosity': 0.043, 'Perceptions of corruption': 0.055}
# {'_id': ObjectId('5fd505d5644cf0d4de07d64b'), 'Overall rank': 105, 'Country or region': 'Laos', 'Score': 4.796, 'GDP per capita': 0.764, 'Social support': 1.03, 'Healthy life expectancy': 0.551, 'Freedom to make life choices': 0.547, 'Generosity': 0.266, 'Perceptions of corruption': 0.16399999999999998}
# {'_id': ObjectId('5fd505d5644cf0d4de07d64c'), 'Overall rank': 106, 'Country or region': 'South Africa', 'Score': 4.7219999999999995, 'GDP per capita': 0.96, 'Social support': 1.351, 'Healthy life expectancy': 0.469, 'Freedom to make life choices': 0.389, 'Generosity': 0.13, 'Perceptions of corruption': 0.055}
# {'_id': ObjectId('5fd505d5644cf0d4de07d64d'), 'Overall rank': 107, 'Country or region': 'Albania', 'Score': 4.718999999999999, 'GDP per capita': 0.9470000000000001, 'Social support': 0.848, 'Healthy life expectancy': 0.8740000000000001, 'Freedom to make life choices': 0.38299999999999995, 'Generosity': 0.17800000000000002, 'Perceptions of corruption': 0.027000000000000003}
# {'_id': ObjectId('5fd505d5644cf0d4de07d64e'), 'Overall rank': 108, 'Country or region': 'Venezuela', 'Score': 4.707, 'GDP per capita': 0.96, 'Social support': 1.4269999999999998, 'Healthy life expectancy': 0.805, 'Freedom to make life choices': 0.154, 'Generosity': 0.064, 'Perceptions of corruption': 0.047}
# {'_id': ObjectId('5fd505d5644cf0d4de07d64f'), 'Overall rank': 109, 'Country or region': 'Cambodia', 'Score': 4.7, 'GDP per capita': 0.574, 'Social support': 1.122, 'Healthy life expectancy': 0.637, 'Freedom to make life choices': 0.609, 'Generosity': 0.23199999999999998, 'Perceptions of corruption': 0.062}
# {'_id': ObjectId('5fd505d5644cf0d4de07d650'), 'Overall rank': 110, 'Country or region': 'Palestinian Territories', 'Score': 4.696000000000001, 'GDP per capita': 0.657, 'Social support': 1.247, 'Healthy life expectancy': 0.672, 'Freedom to make life choices': 0.225, 'Generosity': 0.10300000000000001, 'Perceptions of corruption': 0.066}
# {'_id': ObjectId('5fd505d5644cf0d4de07d651'), 'Overall rank': 111, 'Country or region': 'Senegal', 'Score': 4.681, 'GDP per capita': 0.45, 'Social support': 1.1340000000000001, 'Healthy life expectancy': 0.5710000000000001, 'Freedom to make life choices': 0.292, 'Generosity': 0.153, 'Perceptions of corruption': 0.07200000000000001}
# {'_id': ObjectId('5fd505d5644cf0d4de07d652'), 'Overall rank': 112, 'Country or region': 'Somalia', 'Score': 4.668, 'GDP per capita': 0.0, 'Social support': 0.698, 'Healthy life expectancy': 0.268, 'Freedom to make life choices': 0.5589999999999999, 'Generosity': 0.243, 'Perceptions of corruption': 0.27}
# {'_id': ObjectId('5fd505d5644cf0d4de07d653'), 'Overall rank': 113, 'Country or region': 'Namibia', 'Score': 4.638999999999999, 'GDP per capita': 0.879, 'Social support': 1.3130000000000002, 'Healthy life expectancy': 0.47700000000000004, 'Freedom to make life choices': 0.401, 'Generosity': 0.07, 'Perceptions of corruption': 0.055999999999999994}
# {'_id': ObjectId('5fd505d5644cf0d4de07d654'), 'Overall rank': 114, 'Country or region': 'Niger', 'Score': 4.628, 'GDP per capita': 0.138, 'Social support': 0.774, 'Healthy life expectancy': 0.366, 'Freedom to make life choices': 0.318, 'Generosity': 0.188, 'Perceptions of corruption': 0.102}
# {'_id': ObjectId('5fd505d5644cf0d4de07d655'), 'Overall rank': 115, 'Country or region': 'Burkina Faso', 'Score': 4.587, 'GDP per capita': 0.331, 'Social support': 1.056, 'Healthy life expectancy': 0.38, 'Freedom to make life choices': 0.255, 'Generosity': 0.177, 'Perceptions of corruption': 0.113}
# {'_id': ObjectId('5fd505d5644cf0d4de07d656'), 'Overall rank': 116, 'Country or region': 'Armenia', 'Score': 4.559, 'GDP per capita': 0.85, 'Social support': 1.055, 'Healthy life expectancy': 0.815, 'Freedom to make life choices': 0.28300000000000003, 'Generosity': 0.095, 'Perceptions of corruption': 0.064}
# {'_id': ObjectId('5fd505d5644cf0d4de07d657'), 'Overall rank': 117, 'Country or region': 'Iran', 'Score': 4.548, 'GDP per capita': 1.1, 'Social support': 0.8420000000000001, 'Healthy life expectancy': 0.785, 'Freedom to make life choices': 0.305, 'Generosity': 0.27, 'Perceptions of corruption': 0.125}
# {'_id': ObjectId('5fd505d5644cf0d4de07d658'), 'Overall rank': 118, 'Country or region': 'Guinea', 'Score': 4.534, 'GDP per capita': 0.38, 'Social support': 0.8290000000000001, 'Healthy life expectancy': 0.375, 'Freedom to make life choices': 0.332, 'Generosity': 0.207, 'Perceptions of corruption': 0.086}
# {'_id': ObjectId('5fd505d5644cf0d4de07d659'), 'Overall rank': 119, 'Country or region': 'Georgia', 'Score': 4.519, 'GDP per capita': 0.8859999999999999, 'Social support': 0.6659999999999999, 'Healthy life expectancy': 0.752, 'Freedom to make life choices': 0.34600000000000003, 'Generosity': 0.043, 'Perceptions of corruption': 0.16399999999999998}
# {'_id': ObjectId('5fd505d5644cf0d4de07d65a'), 'Overall rank': 120, 'Country or region': 'Gambia', 'Score': 4.516, 'GDP per capita': 0.308, 'Social support': 0.9390000000000001, 'Healthy life expectancy': 0.428, 'Freedom to make life choices': 0.382, 'Generosity': 0.26899999999999996, 'Perceptions of corruption': 0.16699999999999998}
# {'_id': ObjectId('5fd505d5644cf0d4de07d65b'), 'Overall rank': 121, 'Country or region': 'Kenya', 'Score': 4.5089999999999995, 'GDP per capita': 0.512, 'Social support': 0.983, 'Healthy life expectancy': 0.581, 'Freedom to make life choices': 0.431, 'Generosity': 0.37200000000000005, 'Perceptions of corruption': 0.053}
# {'_id': ObjectId('5fd505d5644cf0d4de07d65c'), 'Overall rank': 122, 'Country or region': 'Mauritania', 'Score': 4.49, 'GDP per capita': 0.57, 'Social support': 1.167, 'Healthy life expectancy': 0.489, 'Freedom to make life choices': 0.066, 'Generosity': 0.106, 'Perceptions of corruption': 0.08800000000000001}
# {'_id': ObjectId('5fd505d5644cf0d4de07d65d'), 'Overall rank': 123, 'Country or region': 'Mozambique', 'Score': 4.466, 'GDP per capita': 0.204, 'Social support': 0.986, 'Healthy life expectancy': 0.39, 'Freedom to make life choices': 0.494, 'Generosity': 0.19699999999999998, 'Perceptions of corruption': 0.138}
# {'_id': ObjectId('5fd505d5644cf0d4de07d65e'), 'Overall rank': 124, 'Country or region': 'Tunisia', 'Score': 4.461, 'GDP per capita': 0.9209999999999999, 'Social support': 1.0, 'Healthy life expectancy': 0.815, 'Freedom to make life choices': 0.16699999999999998, 'Generosity': 0.059000000000000004, 'Perceptions of corruption': 0.055}
# {'_id': ObjectId('5fd505d5644cf0d4de07d65f'), 'Overall rank': 125, 'Country or region': 'Bangladesh', 'Score': 4.456, 'GDP per capita': 0.562, 'Social support': 0.9279999999999999, 'Healthy life expectancy': 0.723, 'Freedom to make life choices': 0.527, 'Generosity': 0.166, 'Perceptions of corruption': 0.14300000000000002}
# {'_id': ObjectId('5fd505d5644cf0d4de07d660'), 'Overall rank': 126, 'Country or region': 'Iraq', 'Score': 4.437, 'GDP per capita': 1.043, 'Social support': 0.98, 'Healthy life expectancy': 0.574, 'Freedom to make life choices': 0.24100000000000002, 'Generosity': 0.14800000000000002, 'Perceptions of corruption': 0.08900000000000001}
# {'_id': ObjectId('5fd505d5644cf0d4de07d661'), 'Overall rank': 127, 'Country or region': 'Congo (Kinshasa)', 'Score': 4.418, 'GDP per capita': 0.094, 'Social support': 1.125, 'Healthy life expectancy': 0.35700000000000004, 'Freedom to make life choices': 0.26899999999999996, 'Generosity': 0.212, 'Perceptions of corruption': 0.053}
# {'_id': ObjectId('5fd505d5644cf0d4de07d662'), 'Overall rank': 128, 'Country or region': 'Mali', 'Score': 4.39, 'GDP per capita': 0.385, 'Social support': 1.105, 'Healthy life expectancy': 0.308, 'Freedom to make life choices': 0.327, 'Generosity': 0.153, 'Perceptions of corruption': 0.052000000000000005}
# {'_id': ObjectId('5fd505d5644cf0d4de07d663'), 'Overall rank': 129, 'Country or region': 'Sierra Leone', 'Score': 4.374, 'GDP per capita': 0.268, 'Social support': 0.841, 'Healthy life expectancy': 0.242, 'Freedom to make life choices': 0.309, 'Generosity': 0.252, 'Perceptions of corruption': 0.045}
# {'_id': ObjectId('5fd505d5644cf0d4de07d664'), 'Overall rank': 130, 'Country or region': 'Sri Lanka', 'Score': 4.3660000000000005, 'GDP per capita': 0.9490000000000001, 'Social support': 1.265, 'Healthy life expectancy': 0.831, 'Freedom to make life choices': 0.47, 'Generosity': 0.244, 'Perceptions of corruption': 0.047}
# {'_id': ObjectId('5fd505d5644cf0d4de07d665'), 'Overall rank': 131, 'Country or region': 'Myanmar', 'Score': 4.36, 'GDP per capita': 0.71, 'Social support': 1.181, 'Healthy life expectancy': 0.555, 'Freedom to make life choices': 0.525, 'Generosity': 0.5660000000000001, 'Perceptions of corruption': 0.172}
# {'_id': ObjectId('5fd505d5644cf0d4de07d666'), 'Overall rank': 132, 'Country or region': 'Chad', 'Score': 4.35, 'GDP per capita': 0.35, 'Social support': 0.7659999999999999, 'Healthy life expectancy': 0.192, 'Freedom to make life choices': 0.174, 'Generosity': 0.198, 'Perceptions of corruption': 0.078}
# {'_id': ObjectId('5fd505d5644cf0d4de07d667'), 'Overall rank': 133, 'Country or region': 'Ukraine', 'Score': 4.332, 'GDP per capita': 0.82, 'Social support': 1.39, 'Healthy life expectancy': 0.7390000000000001, 'Freedom to make life choices': 0.17800000000000002, 'Generosity': 0.187, 'Perceptions of corruption': 0.01}
# {'_id': ObjectId('5fd505d5644cf0d4de07d668'), 'Overall rank': 134, 'Country or region': 'Ethiopia', 'Score': 4.2860000000000005, 'GDP per capita': 0.336, 'Social support': 1.033, 'Healthy life expectancy': 0.532, 'Freedom to make life choices': 0.344, 'Generosity': 0.209, 'Perceptions of corruption': 0.1}
# {'_id': ObjectId('5fd505d5644cf0d4de07d669'), 'Overall rank': 135, 'Country or region': 'Swaziland', 'Score': 4.212, 'GDP per capita': 0.8109999999999999, 'Social support': 1.149, 'Healthy life expectancy': 0.0, 'Freedom to make life choices': 0.313, 'Generosity': 0.07400000000000001, 'Perceptions of corruption': 0.135}
# {'_id': ObjectId('5fd505d5644cf0d4de07d66a'), 'Overall rank': 136, 'Country or region': 'Uganda', 'Score': 4.189, 'GDP per capita': 0.332, 'Social support': 1.069, 'Healthy life expectancy': 0.44299999999999995, 'Freedom to make life choices': 0.35600000000000004, 'Generosity': 0.252, 'Perceptions of corruption': 0.06}
# {'_id': ObjectId('5fd505d5644cf0d4de07d66b'), 'Overall rank': 137, 'Country or region': 'Egypt', 'Score': 4.166, 'GDP per capita': 0.9129999999999999, 'Social support': 1.0390000000000001, 'Healthy life expectancy': 0.644, 'Freedom to make life choices': 0.24100000000000002, 'Generosity': 0.076, 'Perceptions of corruption': 0.067}
# {'_id': ObjectId('5fd505d5644cf0d4de07d66c'), 'Overall rank': 138, 'Country or region': 'Zambia', 'Score': 4.107, 'GDP per capita': 0.578, 'Social support': 1.058, 'Healthy life expectancy': 0.426, 'Freedom to make life choices': 0.431, 'Generosity': 0.247, 'Perceptions of corruption': 0.087}
# {'_id': ObjectId('5fd505d5644cf0d4de07d66d'), 'Overall rank': 139, 'Country or region': 'Togo', 'Score': 4.085, 'GDP per capita': 0.275, 'Social support': 0.5720000000000001, 'Healthy life expectancy': 0.41, 'Freedom to make life choices': 0.293, 'Generosity': 0.177, 'Perceptions of corruption': 0.085}
# {'_id': ObjectId('5fd505d5644cf0d4de07d66e'), 'Overall rank': 140, 'Country or region': 'India', 'Score': 4.015, 'GDP per capita': 0.755, 'Social support': 0.765, 'Healthy life expectancy': 0.588, 'Freedom to make life choices': 0.498, 'Generosity': 0.2, 'Perceptions of corruption': 0.085}
# {'_id': ObjectId('5fd505d5644cf0d4de07d66f'), 'Overall rank': 141, 'Country or region': 'Liberia', 'Score': 3.975, 'GDP per capita': 0.073, 'Social support': 0.922, 'Healthy life expectancy': 0.44299999999999995, 'Freedom to make life choices': 0.37, 'Generosity': 0.233, 'Perceptions of corruption': 0.033}
# {'_id': ObjectId('5fd505d5644cf0d4de07d670'), 'Overall rank': 142, 'Country or region': 'Comoros', 'Score': 3.9730000000000003, 'GDP per capita': 0.27399999999999997, 'Social support': 0.757, 'Healthy life expectancy': 0.505, 'Freedom to make life choices': 0.142, 'Generosity': 0.275, 'Perceptions of corruption': 0.078}
# {'_id': ObjectId('5fd505d5644cf0d4de07d671'), 'Overall rank': 143, 'Country or region': 'Madagascar', 'Score': 3.9330000000000003, 'GDP per capita': 0.27399999999999997, 'Social support': 0.9159999999999999, 'Healthy life expectancy': 0.555, 'Freedom to make life choices': 0.14800000000000002, 'Generosity': 0.16899999999999998, 'Perceptions of corruption': 0.040999999999999995}
# {'_id': ObjectId('5fd505d5644cf0d4de07d672'), 'Overall rank': 144, 'Country or region': 'Lesotho', 'Score': 3.802, 'GDP per capita': 0.489, 'Social support': 1.169, 'Healthy life expectancy': 0.168, 'Freedom to make life choices': 0.359, 'Generosity': 0.107, 'Perceptions of corruption': 0.09300000000000001}
# {'_id': ObjectId('5fd505d5644cf0d4de07d673'), 'Overall rank': 145, 'Country or region': 'Burundi', 'Score': 3.775, 'GDP per capita': 0.046, 'Social support': 0.447, 'Healthy life expectancy': 0.38, 'Freedom to make life choices': 0.22, 'Generosity': 0.17600000000000002, 'Perceptions of corruption': 0.18}
# {'_id': ObjectId('5fd505d5644cf0d4de07d674'), 'Overall rank': 146, 'Country or region': 'Zimbabwe', 'Score': 3.6630000000000003, 'GDP per capita': 0.366, 'Social support': 1.114, 'Healthy life expectancy': 0.433, 'Freedom to make life choices': 0.361, 'Generosity': 0.151, 'Perceptions of corruption': 0.08900000000000001}
# {'_id': ObjectId('5fd505d5644cf0d4de07d675'), 'Overall rank': 147, 'Country or region': 'Haiti', 'Score': 3.597, 'GDP per capita': 0.32299999999999995, 'Social support': 0.688, 'Healthy life expectancy': 0.449, 'Freedom to make life choices': 0.026000000000000002, 'Generosity': 0.419, 'Perceptions of corruption': 0.11}
# {'_id': ObjectId('5fd505d5644cf0d4de07d676'), 'Overall rank': 148, 'Country or region': 'Botswana', 'Score': 3.488, 'GDP per capita': 1.041, 'Social support': 1.145, 'Healthy life expectancy': 0.5379999999999999, 'Freedom to make life choices': 0.455, 'Generosity': 0.025, 'Perceptions of corruption': 0.1}
# {'_id': ObjectId('5fd505d5644cf0d4de07d677'), 'Overall rank': 149, 'Country or region': 'Syria', 'Score': 3.4619999999999997, 'GDP per capita': 0.619, 'Social support': 0.37799999999999995, 'Healthy life expectancy': 0.44, 'Freedom to make life choices': 0.013000000000000001, 'Generosity': 0.331, 'Perceptions of corruption': 0.141}
# {'_id': ObjectId('5fd505d5644cf0d4de07d678'), 'Overall rank': 150, 'Country or region': 'Malawi', 'Score': 3.41, 'GDP per capita': 0.191, 'Social support': 0.56, 'Healthy life expectancy': 0.495, 'Freedom to make life choices': 0.44299999999999995, 'Generosity': 0.218, 'Perceptions of corruption': 0.08900000000000001}
# {'_id': ObjectId('5fd505d5644cf0d4de07d679'), 'Overall rank': 151, 'Country or region': 'Yemen', 'Score': 3.38, 'GDP per capita': 0.287, 'Social support': 1.163, 'Healthy life expectancy': 0.46299999999999997, 'Freedom to make life choices': 0.14300000000000002, 'Generosity': 0.10800000000000001, 'Perceptions of corruption': 0.077}
# {'_id': ObjectId('5fd505d5644cf0d4de07d67a'), 'Overall rank': 152, 'Country or region': 'Rwanda', 'Score': 3.3339999999999996, 'GDP per capita': 0.359, 'Social support': 0.711, 'Healthy life expectancy': 0.614, 'Freedom to make life choices': 0.555, 'Generosity': 0.217, 'Perceptions of corruption': 0.41100000000000003}
# {'_id': ObjectId('5fd505d5644cf0d4de07d67b'), 'Overall rank': 153, 'Country or region': 'Tanzania', 'Score': 3.2310000000000003, 'GDP per capita': 0.47600000000000003, 'Social support': 0.885, 'Healthy life expectancy': 0.499, 'Freedom to make life choices': 0.41700000000000004, 'Generosity': 0.276, 'Perceptions of corruption': 0.147}
# {'_id': ObjectId('5fd505d5644cf0d4de07d67c'), 'Overall rank': 154, 'Country or region': 'Afghanistan', 'Score': 3.2030000000000003, 'GDP per capita': 0.35, 'Social support': 0.517, 'Healthy life expectancy': 0.361, 'Freedom to make life choices': 0.0, 'Generosity': 0.158, 'Perceptions of corruption': 0.025}
# {'_id': ObjectId('5fd505d5644cf0d4de07d67d'), 'Overall rank': 155, 'Country or region': 'Central African Republic', 'Score': 3.083, 'GDP per capita': 0.026000000000000002, 'Social support': 0.0, 'Healthy life expectancy': 0.105, 'Freedom to make life choices': 0.225, 'Generosity': 0.235, 'Perceptions of corruption': 0.035}
# {'_id': ObjectId('5fd505d5644cf0d4de07d67e'), 'Overall rank': 156, 'Country or region': 'South Sudan', 'Score': 2.853, 'GDP per capita': 0.306, 'Social support': 0.575, 'Healthy life expectancy': 0.295, 'Freedom to make life choices': 0.01, 'Generosity': 0.20199999999999999, 'Perceptions of corruption': 0.091}

# %%
df_ranking = pd.DataFrame(list(db.happy_ranking.find({})))
df_ranking
# Out:
#                           _id  Overall rank         Country or region  Score  \
# 0    5fd505d5644cf0d4de07d5e3             1                   Finland  7.769
# 1    5fd505d5644cf0d4de07d5e4             2                   Denmark  7.600
# 2    5fd505d5644cf0d4de07d5e5             3                    Norway  7.554
# 3    5fd505d5644cf0d4de07d5e6             4                   Iceland  7.494
# 4    5fd505d5644cf0d4de07d5e7             5               Netherlands  7.488
# ..                        ...           ...                       ...    ...
# 151  5fd505d5644cf0d4de07d67a           152                    Rwanda  3.334
# 152  5fd505d5644cf0d4de07d67b           153                  Tanzania  3.231
# 153  5fd505d5644cf0d4de07d67c           154               Afghanistan  3.203
# 154  5fd505d5644cf0d4de07d67d           155  Central African Republic  3.083
# 155  5fd505d5644cf0d4de07d67e           156               South Sudan  2.853
#
#      GDP per capita  Social support  Healthy life expectancy  \
# 0             1.340           1.587                    0.986
# 1             1.383           1.573                    0.996
# 2             1.488           1.582                    1.028
# 3             1.380           1.624                    1.026
# 4             1.396           1.522                    0.999
# ..              ...             ...                      ...
# 151           0.359           0.711                    0.614
# 152           0.476           0.885                    0.499
# 153           0.350           0.517                    0.361
# 154           0.026           0.000                    0.105
# 155           0.306           0.575                    0.295
#
#      Freedom to make life choices  Generosity  Perceptions of corruption
# 0                           0.596       0.153                      0.393
# 1                           0.592       0.252                      0.410
# 2                           0.603       0.271                      0.341
# 3                           0.591       0.354                      0.118
# 4                           0.557       0.322                      0.298
# ..                            ...         ...                        ...
# 151                         0.555       0.217                      0.411
# 152                         0.417       0.276                      0.147
# 153                         0.000       0.158                      0.025
# 154                         0.225       0.235                      0.035
# 155                         0.010       0.202                      0.091
#
# [156 rows x 10 columns]

# %%
df_income = pd.DataFrame(list(db.income_group.find({})))
df_income.head
# Out:
# <bound method NDFrame.head of                           _id                Country Code  \
# 0    5fd505d0644cf0d4de07d509            Afghanistan  AFG
# 1    5fd505d0644cf0d4de07d50a                Albania  ALB
# 2    5fd505d0644cf0d4de07d50b                Algeria  DZA
# 3    5fd505d0644cf0d4de07d50c         American Samoa  ASM
# 4    5fd505d0644cf0d4de07d50d                Andorra  AND
# ..                        ...                    ...  ...
# 213  5fd505d0644cf0d4de07d5de  Virgin Islands (U.S.)  VIR
# 214  5fd505d0644cf0d4de07d5df     West Bank and Gaza  PSE
# 215  5fd505d0644cf0d4de07d5e0            Yemen, Rep.  YEM
# 216  5fd505d0644cf0d4de07d5e1                 Zambia  ZMB
# 217  5fd505d0644cf0d4de07d5e2               Zimbabwe  ZWE
#
#                          Region         Income group
# 0                    South Asia           Low income
# 1         Europe & Central Asia  Upper middle income
# 2    Middle East & North Africa  Lower middle income
# 3           East Asia & Pacific  Upper middle income
# 4         Europe & Central Asia          High income
# ..                          ...                  ...
# 213   Latin America & Caribbean          High income
# 214  Middle East & North Africa  Lower middle income
# 215  Middle East & North Africa           Low income
# 216          Sub-Saharan Africa  Lower middle income
# 217          Sub-Saharan Africa  Lower middle income
#
# [218 rows x 5 columns]>

# %%
combined = pd.merge(df_ranking, df_income, left_on='Country or region', right_on='Country')
#combined

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136 entries, 0 to 135
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   _id_x                         136 non-null    object
#  1   Overall rank                  136 non-null    int64
#  2   Country or region             136 non-null    object
#  3   Score                         136 non-null    float64
#  4   GDP per capita                136 non-null    float64
#  5   Social support                136 non-null    float64
#  6   Healthy life expectancy       136 non-null    float64
#  7   Freedom to make life choices  136 non-null    float64
#  8   Generosity                    136 non-null    float64
#  9   Perceptions of corruption     136 non-null    float64
#  10  _id_y                         136 non-null    object
#  11  Country                       136 non-null    object
#  12  Code                          136 non-null    object
#  13  Region                        136 non-null    object
#  14  Income group                  136 non-null    object
# dtypes: float64(7), int64(1), object(7)
# memory usage: 17.0+ KB

# %%
#print(combined[['Income group','Country or region','Country', 'Score','Perceptions of corruption']])
